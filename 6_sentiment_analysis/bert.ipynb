# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import nltk
import requests

from sklearn.model_selection import train_test_split
from pathlib import Path
from zipfile import ZipFile

# %%
MODEL_ID = "bert"

MODEL_DIR = Path("./models")
LOG_DIR = Path("./log")
DOWNLOAD_DIR = Path("./downloads")

TRAIN_PATH = Path("./data/train.csv")
TEST_PATH = Path("./data/test.csv")

EMBEDDING_DIMS = 300

SEED = 1
BATCH_SIZE = 64

# %%
MODEL_DIR.mkdir(parents = True, exist_ok = True)
LOG_DIR.mkdir(parents = True, exist_ok = True)
DOWNLOAD_DIR.mkdir(parents = True, exist_ok = True)

# %%
checkpoint_path = MODEL_DIR / (MODEL_ID + ".{epoch:03d}-{val_accuracy:.4f}.h5")
log_path = (LOG_DIR / MODEL_ID).with_suffix(".csv")

print(checkpoint_path)
print(log_path)
# Out:
# models/bert.{epoch:03d}-{val_accuracy:.4f}.h5
# log/bert.csv

# %%
# Set global seed for reproducible results
tf.random.set_seed(SEED)

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# ## Preprocessing

# %%
df = pd.read_csv(TRAIN_PATH)
df.head()
# Out:
#    review_id                                             review  rating
# 0          0  Ga disappointed neat products .. Meletot Hilsn...       1
# 1          1    Rdtanya replace broken glass, broken chargernya       1
# 2          2  Nyesel bngt dsni shopping antecedent photo mes...       1
# 3          3      Sent a light blue suit goods ga want a refund       1
# 4          4  Pendants came with dents and scratches on its ...       1

# %%
df[df['review'] == 'Good quality']
# Out:
# 3.8181818181818183

# %%
df.shape
# Out:
# (146811, 3)

# %%
review_rating = dict()

for review, group in df[df.duplicated(subset=['review'], keep = False)].groupby("review"):
    review_rating[review] = group["rating"].mean()

review_rating
# Out:
# {'  Excellent product quality': 4.666666666666667,
#  '  Free shipping product price good good good seller Response': 3.0,
#  '  Good product quality': 3.3333333333333335,
#  '  Product quality standards.': 2.0,
#  ' Acceptable price': 2.0,
#  ' Accommodating seller': 3.0,
#  ' Accommodating seller Good quality': 3.0,
#  ' Accommodating seller Item shipped quickly': 3.0,
#  ' Accommodating seller Well-packaged': 3.0,
#  ' Accommodating seller Well-packaged Item shipped quickly': 3.0,
#  ' Are not worth the money': 1.0,
#  ' Awesome awesome merchandise quality merchandise quality': 4.464788732394366,
#  ' Awesome awesome merchandise quality merchandise quality merchandise awesome awesome quality goods quality': 4.0,
#  ' Awesome awesome merchandise quality merchandise quality merchandise awesome quality': 4.5,
#  ' Awesome awesome product quality CP CP value of the value of awesome awesome service': 4.5,
#  ' Awesome awesome quality goods CP value awesome service': 4.457831325301205,
#  ' Awesome awesome quality goods CP value awesome service awesome speed of the ship': 4.818181818181818,
#  ' Awesome awesome quality goods CP value of the awesome speed of the ship': 4.578947368421052,
#  ' Awesome awesome quality goods CP values \u200b\u200bawesome product quality': 4.5,
#  ' Awesome awesome quality merchandise quality merchandise awesome CP value of awesome speed of the ship': 4.571428571428571,
#  ' Awesome awesome quality merchandise quality merchandise awesome awesome service value CP': 4.333333333333333,
#  ' Awesome awesome quality merchandise quality merchandise awesome awesome value CP CP value': 4.333333333333333,
#  ' Awesome awesome quality merchandise quality merchandise awesome speed of the ship': 4.516129032258065,
#  ' Awesome awesome quality merchandise quality merchandise awesome speed of the ship awesome awesome value CP CP value': 5.0,
#  ' Awesome awesome quality merchandise quality merchandise awesome speed of the ship awesome speed of the ship': 4.5,
#  ' Awesome awesome quality merchandise quality merchandise awesome speed of the ship awesome value CP': 4.4375,
#  ' Awesome awesome quality merchandise quality merchandise awesome speed of the ship rocking CP value awesome service': 4.666666666666667,
#  ' Awesome awesome quality merchandise quality merchandise awesome value CP': 4.405405405405405,
#  ' Awesome awesome quality merchandise value CP': 4.489208633093525,
#  ' Awesome awesome quality merchandise value of CP CP awesome value': 4.428571428571429,
#  ' Awesome awesome quality of goods and services': 4.545454545454546,
#  ' Awesome awesome quality of goods shipped speed': 4.430656934306569,
#  ' Awesome awesome quality of goods shipped speed awesome product quality': 4.333333333333333,
#  ' Awesome awesome quality of goods shipped speed awesome service': 4.285714285714286,
#  ' Awesome awesome quality of goods shipped speed awesome value CP': 4.382352941176471,
#  ' Awesome awesome quality of goods shipped speed of the awesome speed of the ship': 4.8,
#  ' Awesome awesome quality of goods shipped speed of the awesome speed of the ship awesome value CP': 4.5,
#  ' Awesome awesome quality of goods shipped speed service awesome awesome value CP': 4.0,
#  ' Awesome awesome quality of goods shipped speed value CP awesome awesome service': 4.543478260869565,
#  ' Awesome awesome quality of goods shipped speed value CP awesome awesome speed of the ship': 4.5,
#  ' Awesome awesome quality of goods shipped speed value CP awesome awesome value CP': 4.5,
#  ' Awesome awesome service quality merchandise awesome CP value of awesome speed of the ship': 4.0,
#  ' Awesome awesome service quality merchandise awesome speed of the ship': 4.333333333333333,
#  ' Awesome awesome service quality merchandise awesome value CP': 4.333333333333333,
#  ' Awesome awesome speed of delivery of goods awesome quality service': 4.572916666666667,
#  ' Awesome awesome speed of delivery of goods quality': 4.483214649033571,
#  ' Awesome awesome speed of delivery service': 4.543103448275862,
#  ' Awesome awesome speed of the ship CP value awesome service': 4.433333333333334,
#  ' Awesome awesome speed of the ship CP value awesome service awesome product quality': 4.5,
#  ' Awesome awesome speed of the ship CP value of awesome speed of the ship': 5.0,
#  ' Awesome awesome speed of the ship CP values \u200b\u200bawesome awesome quality of goods and services': 4.545454545454546,
#  ' Awesome awesome speed of the ship CP values \u200b\u200bawesome product quality': 4.526315789473684,
#  ' Awesome awesome speed of the ship merchandise quality awesome awesome CP value of goods quality': 4.5,
#  ' Awesome awesome speed of the ship merchandise quality awesome awesome value CP CP value': 4.444444444444445,
#  ' Awesome awesome speed of the ship merchandise quality awesome awesome value CP CP value awesome service': 4.388888888888889,
#  ' Awesome awesome speed of the ship merchandise quality awesome service awesome value CP': 4.666666666666667,
#  ' Awesome awesome speed of the ship merchandise quality awesome speed of the ship awesome awesome CP CP value value': 5.0,
#  ' Awesome awesome speed of the ship merchandise quality awesome speed of the ship awesome quality of goods': 4.5,
#  ' Awesome awesome speed of the ship merchandise quality awesome speed of the ship awesome service': 5.0,
#  ' Awesome awesome speed of the ship merchandise quality awesome speed of the ship awesome value CP': 4.533333333333333,
#  ' Awesome awesome speed of the ship merchandise quality awesome speed of the ship rocking CP value awesome service': 4.333333333333333,
#  ' Awesome awesome speed of the ship merchandise quality merchandise awesome awesome quality of CP value awesome service': 4.411764705882353,
#  ' Awesome awesome speed of the ship merchandise quality merchandise awesome awesome quality of service': 4.75,
#  ' Awesome awesome speed of the ship merchandise quality merchandise awesome awesome quality value CP': 4.43859649122807,
#  ' Awesome awesome speed of the ship merchandise quality merchandise awesome quality': 4.625,
#  ' Awesome awesome speed of the ship merchandise quality 👍': 5.0,
#  " Awesome awesome speed of the ship's delivery speed": 4.524752475247524,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods": 4.559210526315789,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome CP values \u200b\u200bawesome service awesome service": 4.0,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome awesome CP value of commodity quality": 4.5,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome awesome quality goods CP value awesome service": 4.333333333333333,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome awesome quality merchandise value CP": 5.0,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome awesome service value CP": 4.456310679611651,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome awesome value CP CP value": 4.571428571428571,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome awesome value CP CP value awesome service": 4.565217391304348,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome awesome value CP CP value awesome service awesome service": 4.666666666666667,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome service": 4.25,
#  " Awesome awesome speed of the ship's delivery speed fabulous quality of goods awesome value CP": 4.45816733067729,
#  " Awesome awesome speed of the ship's delivery speed fabulous service": 4.5,
#  " Awesome awesome speed of the ship's service quality merchandise awesome awesome awesome quality merchandise value CP": 4.5,
#  " Awesome awesome speed of the ship's value CP": 4.487603305785124,
#  ' Awesome product quality  Awesome speed of the ship': 4.5,
#  ' Awesome product quality, awesome speed of the ship': 4.0,
#  ' Awesome service awesome CP value of awesome speed of the ship': 4.0,
#  ' Awesome service awesome CP values \u200b\u200bawesome awesome quality of goods shipped speed': 4.4,
#  ' Awesome service awesome awesome CP value of commodity quality': 5.0,
#  ' Awesome service awesome product quality': 4.5,
#  ' Awesome service awesome service': 4.428571428571429,
#  ' Awesome service awesome speed of the ship': 4.266666666666667,
#  ' Awesome service awesome speed of the ship awesome quality of goods': 4.4,
#  ' Awesome service awesome value CP': 4.428571428571429,
#  ' Awesome speed of the ship  Awesome product quality': 5.0,
#  ' Awesome speed of the ship  Awesome product quality  CP values \u200b\u200bawesome': 4.666666666666667,
#  ' Awesome speed of the ship  Awesome product quality  CP values \u200b\u200bawesome  Awesome service': 5.0,
#  ' Awesome speed of the ship - awesome product quality': 4.0,
#  ' Awesome speed of the ship CP values \u200b\u200bawesome awesome awesome merchandise quality of service': 5.0,
#  ' Awesome speed of the ship CP values \u200b\u200bawesome awesome service': 5.0,
#  ' Awesome speed of the ship awesome awesome quality goods CP value awesome service': 4.510903426791277,
#  ' Awesome speed of the ship awesome awesome quality goods CP value awesome service awesome service': 4.5,
#  ' Awesome speed of the ship awesome awesome quality goods CP value awesome service awesome service awesome service': 4.5,
#  ' Awesome speed of the ship awesome awesome quality goods CP value awesome service awesome value CP': 4.75,
#  ' Awesome speed of the ship awesome awesome quality goods CP values \u200b\u200bawesome awesome quality of goods and services': 4.0,
#  ' Awesome speed of the ship awesome awesome quality goods shipped speed': 4.7,
#  ' Awesome speed of the ship awesome awesome quality merchandise value CP': 4.487719298245614,
#  ' Awesome speed of the ship awesome awesome value CP CP value': 4.333333333333333,
#  ' Awesome speed of the ship awesome awesome value CP CP value of awesome quality of goods': 4.5,
#  ' Awesome speed of the ship awesome speed of the ship awesome awesome CP value of goods quality': 4.666666666666667,
#  ' Awesome speed of the ship awesome speed of the ship awesome awesome quality goods quality goods': 4.0,
#  ' Awesome speed of the ship awesome speed of the ship awesome speed of the ship': 4.388888888888889,
#  ' Awesome speed of the ship awesome speed of the ship awesome speed of the ship awesome awesome quality goods CP value awesome service': 4.5,
#  ' Awesome speed of the ship awesome speed of the ship awesome speed of the ship awesome awesome quality merchandise value CP': 5.0,
#  ' Awesome speed of the ship awesome speed of the ship awesome speed of the ship awesome speed of the ship': 4.857142857142857,
#  ' Awesome speed of the ship awesome speed of the ship awesome speed of the ship awesome speed of the ship awesome speed of the ship': 4.75,
#  ' Awesome speed of the ship awesome speed of the ship awesome value CP': 4.470588235294118,
#  ' Awesome speed of the ship awesome speed of the ship rocking CP value awesome service': 4.25,
#  ' Awesome speed of the ship fabulous service awesome awesome CP value of commodity quality': 4.333333333333333,
#  ' Awesome speed of the ship fabulous service awesome product quality': 4.428571428571429,
#  ' Awesome speed of the ship fabulous service awesome value CP': 4.75,
#  ' Awesome speed of the ship general merchandise quality': 2.3333333333333335,
#  ' Awesome speed of the ship, awesome product quality': 4.0,
#  ' Awesome speed of the ship, awesome value CP': 4.5,
#  ' Bad bad bad delivery speed quality merchandise value CP': 1.0,
#  ' Bad bad delivery speed of delivery speed': 1.5,
#  ' Bad bad quality goods quality goods': 1.0,
#  ' Bad bad quality merchandise value CP': 1.0,
#  ' Bad bad quality of goods and services': 1.0,
#  ' Bad bad quality of goods shipped speed': 1.0,
#  ' Bad bad service delivery speed': 1.0,
#  ' CP value awesome service awesome awesome awesome quality of goods shipped speed': 5.0,
#  ' CP value of the ordinary general merchandise quality': 2.0,
#  ' CP value of the ordinary general speed of the ship': 2.5,
#  ' CP value of the poor poor quality goods': 1.0,
#  ' CP values \u200b\u200bawesome awesome awesome CP value of commodity quality': 5.0,
#  ' CP values \u200b\u200bawesome awesome awesome CP value of goods shipped speed fabulous quality': 4.0,
#  ' CP values \u200b\u200bawesome awesome awesome CP value of goods shipped speed quality awesome awesome service': 5.0,
#  ' CP values \u200b\u200bawesome awesome awesome CP value of goods shipped speed quality awesome awesome speed of the ship': 4.5,
#  ' CP values \u200b\u200bawesome awesome awesome CP value of merchandise quality awesome speed of the ship': 4.5,
#  ' CP values \u200b\u200bawesome awesome awesome CP value of the speed of the ship': 4.333333333333333,
#  ' CP values \u200b\u200bawesome awesome awesome merchandise quality merchandise quality': 5.0,
#  ' CP values \u200b\u200bawesome awesome awesome merchandise quality of service': 4.2,
#  ' CP values \u200b\u200bawesome awesome awesome merchandise quality of service awesome speed of the ship': 5.0,
#  ' CP values \u200b\u200bawesome awesome awesome quality merchandise quality merchandise awesome speed of the ship': 4.5,
#  ' CP values \u200b\u200bawesome awesome awesome quality merchandise value CP': 4.0,
#  ' CP values \u200b\u200bawesome awesome awesome quality of goods shipped speed': 4.612244897959184,
#  ' CP values \u200b\u200bawesome awesome awesome quality of goods shipped speed awesome service': 4.4,
#  ' CP values \u200b\u200bawesome awesome awesome quality of goods shipped speed of the awesome speed of the ship': 4.666666666666667,
#  ' CP values \u200b\u200bawesome awesome awesome service quality goods': 4.333333333333333,
#  ' CP values \u200b\u200bawesome awesome awesome service service': 5.0,
#  ' CP values \u200b\u200bawesome awesome awesome speed of delivery of goods quality': 4.615384615384615,
#  " CP values \u200b\u200bawesome awesome awesome speed of the ship's delivery speed fabulous quality of goods": 5.0,
#  ' CP values \u200b\u200bawesome awesome awesome value CP CP value': 4.5,
#  ' CP values \u200b\u200bawesome awesome product quality': 4.370967741935484,
#  ' CP values \u200b\u200bawesome awesome service': 4.631578947368421,
#  ' CP values \u200b\u200bawesome awesome speed of the ship': 4.523809523809524,
#  ' CP values \u200b\u200bawesome awesome value CP': 4.40625,
#  ' Damaged / Defective item': 1.0,
#  ' Damaged / Defective item Damaged / Defective item': 1.0,
#  ' Damaged / Defective item Damaged / Defective item Damaged / Defective item Damaged / Defective item Damaged / Defective item Damaged / Defective item Damaged / Defective item Damaged / Defective item': 1.0,
#  ' Damaged / Defective item Damaged packaging': 1.0,
#  ' Damaged / Defective item Will not order again': 1.0,
#  ' Damaged packaging': 1.0,
#  ' Delivery speed is good and good product price': 3.0,
#  ' Delivery speed is good.': 3.0,
#  ' Delivery speed is good. Good product quality.': 3.0,
#  ' Delivery speed is good. Good product quality. Good seller response.': 3.0,
#  ' Delivery speed is good. Good seller response': 3.0,
#  ' Delivery speed is good. Good seller response.': 3.0,
#  ' Delivery speed is good. Good seller response. Good product quality.': 3.0,
#  ' Delivery speed is good. Good seller response. The product price is good.': 3.0,
#  ' Delivery speed is good. The product price is good.': 2.923076923076923,
#  ' Delivery speed is good. The product price is good. Good seller response.': 3.0,
#  ' Delivery speed is not good': 1.3,
#  ' Delivery speed is not good.': 1.375,
#  ' Delivery speed is not good. Good product quality.': 2.6666666666666665,
#  ' Delivery speed is not good. Less good seller response.': 1.0,
#  ' Delivery speed is not good. Product quality standards.': 2.0,
#  ' Delivery speed is very good': 4.3,
#  ' Delivery speed is very good very good product price': 4.666666666666667,
#  " Delivery speed is very good very good product quality is very good seller's response": 4.5,
#  ' Delivery speed is very good.': 4.428571428571429,
#  ' Delivery speed is very good. Delivery speed is very good. Delivery speed is very good.': 4.5,
#  ' Delivery speed is very good. Delivery speed is very good. The response is very good seller.': 4.5,
#  ' Delivery speed is very good. The product price is very good.': 5.0,
#  ' Delivery speed is very good. The product quality is excellent.': 4.571428571428571,
#  ' Delivery speed is very good. The response is very good seller.': 4.476190476190476,
#  ' Delivery speed response good seller good price good product': 3.0,
#  ' Delivery speed response good seller good product good price good product quality': 3.0,
#  ' Delivery time as expected': 2.0588235294117645,
#  ' Excellent quality Very accommodating seller Well-packaged Item shipped immediately Will order again': 4.455089820359281,
#  ' Excellent quality Very accommodating seller Well-packaged Item shipped immediately Will order again ': 4.5,
#  ' Excellent quality Very accommodating seller Well-packaged Item shipped immediately Will order again Will order again': 4.8,
#  ' Excellent quality Very accommodating seller Well-packaged Item shipped immediately Will order again Will order again Will order again': 4.333333333333333,
#  ' Excellent quality Very accommodating seller Well-packaged Item shipped immediately Will order again Will order again Will order again Will order again Will order again': 4.0,
#  ' Excellent quality Very accommodating seller Well-packaged Well-packaged Item shipped immediately': 4.5,
#  ' Excellent quality Very accommodating seller Well-packaged Well-packaged Item shipped immediately Will order again': 4.4,
#  ' Excellent quality Very accommodating seller Well-packaged Will order again': 4.645161290322581,
#  ' Excellent quality Very accommodating seller Well-packaged Will order again Item shipped immediately': 4.666666666666667,
#  ' Excellent quality Very accommodating seller Well-packaged\xa0 Will order again': 4.333333333333333,
#  ' Excellent quality Very accommodating seller Will order again': 4.352941176470588,
#  ' Excellent quality Well-packaged': 4.605263157894737,
#  ' Excellent quality Well-packaged Item shipped immediately': 4.666666666666667,
#  ' Excellent quality Well-packaged Item shipped immediately Will order again': 4.515151515151516,
#  ' Excellent quality Well-packaged Well-packaged Item shipped immediately': 5.0,
#  ' Excellent quality Well-packaged Well-packaged Item shipped immediately Will order again': 4.333333333333333,
#  ' Excellent quality Well-packaged Will order again': 4.594594594594595,
#  ' Excellent quality Well-packaged Will order again Will order again': 4.5,
#  ' Excellent quality Will order again': 4.318181818181818,
#  ' Excellent quality.': 4.666666666666667,
#  ' Excellent quality\xa0': 4.0,
#  ' Excellent quality\xa0 Very accommodating seller': 4.333333333333333,
#  ' Excellent quality\xa0 Well-packaged Item shipped immediately Will order again': 5.0,
#  ' Excellent service by seller': 4.602564102564102,
#  ' Excellent service by seller Excellent service by seller': 4.25,
#  ' Excellent service by seller Fast delivery': 4.555555555555555,
#  ' Excellent service by seller Fast delivery Good product quality Good value for money': 5.0,
#  ' Excellent service by seller Good product quality': 4.5,
#  ' Excellent speed of delivery excellent product quality': 4.538461538461538,
#  ' Fair delivery speed': 2.0,
#  ' Fair value Fair value': 2.0,
#  ' Fair value Fast delivery Fair.': 2.0,
#  ' Fair value Fast delivery, good.': 2.6666666666666665,
#  ' Fair value Poor Quality': 2.0,
#  ' Fair value Poor service from the carrier.': 2.0,
#  ' Fast delivery': 3.9805194805194803,
#  ' Fast delivery Excellent service by seller': 4.487179487179487,
#  ' Fast delivery Excellent service by seller Good product quality': 4.625,
#  ' Fast delivery Excellent service by seller Good product quality Good value for money': 4.75,
#  ' Fast delivery Excellent service by seller Good value for money': 4.2,
#  ' Fast delivery Excellent service by seller Good value for money Good product quality': 4.666666666666667,
#  ' Fast delivery Fair. Fair value': 2.0,
#  ' Fast delivery Fair. Fast delivery Fair.': 3.5,
#  ' Fast delivery Fair. Poor Quality': 2.0,
#  ' Fast delivery Fair. Poor service from the carrier.': 2.0,
#  ' Fast delivery Fair. Poor service from the store.': 2.0,
#  ' Fast delivery Fast delivery': 4.0,
#  ' Fast delivery Fast delivery Fast delivery': 5.0,
#  ' Fast delivery Fast delivery Fast delivery Fast delivery': 4.5,
#  ' Fast delivery Good product quality': 4.625,
#  ' Fast delivery Good product quality Excellent service by seller': 4.5,
#  ' Fast delivery Good product quality Good value for money': 4.166666666666667,
#  ' Fast delivery Good service by seller': 3.0,
#  ' Fast delivery Good value for money': 4.25,
#  ' Fast delivery Good value for money Good product quality': 4.2,
#  ' Fast delivery Product quality is ok': 2.3333333333333335,
#  ' Fast delivery time': 3.08,
#  ' Fast delivery, good. Fast delivery, good.': 3.0,
#  ' Fast delivery, good. Fast delivery, good. Fast delivery, good. Fast delivery, good.': 3.0,
#  ' Fast delivery, good. Good service from the carrier.': 3.0,
#  ' Fast delivery, good. Good service from the carrier. Services provided by the nice shops.': 3.0,
#  ' Fast delivery, good. Good value': 3.0357142857142856,
#  ' Fast delivery, good. Good value Good service from the carrier.': 3.0,
#  ' Fast delivery, good. Good value Product quality good': 3.0,
#  ' Fast delivery, good. Product quality good': 3.0,
#  ' Fast delivery, good. Product quality good Good value': 3.0,
#  ' Fast delivery, good. Services provided by the nice shops.': 3.0,
#  ' Fast delivery, good. Services provided by the nice shops. Good service from the carrier.': 3.0,
#  ' Fast delivery, good. Services provided by the nice shops. Good value': 3.0,
#  ' Fast delivery. Good value for money.': 4.5,
#  ' Free shipping good price good product': 3.0,
#  ' Free shipping good price good product good product price': 3.0,
#  ' Free shipping good price good product good product quality': 3.0,
#  ' Free shipping good price good product good seller Response': 3.0,
#  ' Free shipping product price good good good Delivery speed': 3.0,
#  ' Free shipping product price good good good product quality': 3.0,
#  ' Free shipping product price good good good product quality is good seller Response': 3.0,
#  ' Free shipping product price good good good seller Response': 3.0307692307692307,
#  ' Free shipping the product quality is not good': 3.0,
#  ' Free standard shipping': 2.125,
#  ' Free standard shipping product quality good': 2.75,
#  ' Free standard shipping product quality is not good': 1.0,
#  ' Free standard shipping product quality standards': 2.0,
#  ' Free standard shipping product quality standards seller Response standard': 2.0,
#  ' Free standard shipping product quality standards standard product price': 2.0,
#  " Free standard shipping standard seller's response": 2.3333333333333335,
#  ' Free standard shipping.': 2.2,
#  ' Free standard shipping. Product quality standards.': 2.0,
#  ' Free standard shipping. Standard seller response.': 2.0,
#  ' General merchandise quality awesome speed of the ship': 3.0,
#  ' General merchandise quality common values \u200b\u200bCP': 2.090909090909091,
#  ' General merchandise quality general merchandise quality': 2.090909090909091,
#  ' General merchandise quality general speed of the ship': 2.0,
#  ' Good Good Good CP value of goods shipped speed quality': 3.0,
#  ' Good Good Good Good speed of delivery of goods CP-quality value-added services': 3.210526315789474,
#  ' Good Good Good goods CP-quality value-added services': 3.2,
#  ' Good Good Good goods quality goods quality value CP': 3.0,
#  ' Good Good Services': 3.0,
#  ' Good Good quality of goods and services': 3.0,
#  ' Good Good quality of goods shipped speed': 3.036363636363636,
#  ' Good Good quality of goods shipped speed service': 3.0,
#  ' Good Price': 3.0,
#  ' Good Product Quality': 3.0,
#  ' Good awesome speed of the ship merchandise quality': 3.0,
#  ' Good delivery speed': 3.0,
#  ' Good delivery speed delivery speed good price good product': 3.0,
#  ' Good delivery speed delivery speed well': 3.0,
#  ' Good delivery speed fabulous quality of goods awesome value CP': 4.5,
#  ' Good delivery speed good delivery speed delivery speed well': 3.0,
#  ' Good delivery speed good product quality': 3.0,
#  ' Good delivery speed good value CP': 3.0833333333333335,
#  ' Good delivery speed response is very good seller good product price product quality is good': 3.0,
#  ' Good general quality of goods shipped speed': 2.5,
#  ' Good good good good good good shipping speed delivery speed product quality CP CP value of value-added services': 3.0,
#  ' Good good good good good quality goods shipped speed value of CP CP value services': 3.0,
#  ' Good good good good quality of goods shipped speed services CP value': 3.0,
#  ' Good good good quality of goods shipped speed of delivery speed': 3.0,
#  ' Good good good service delivery speed value CP': 3.2,
#  ' Good good good shipping speed CP value of goods quality': 3.0,
#  ' Good good good shipping speed delivery speed delivery speed': 3.0,
#  ' Good good good shipping speed delivery speed good quality merchandise value CP': 3.4,
#  ' Good good good shipping speed delivery speed product quality': 3.0,
#  ' Good good good shipping speed value CP CP value': 3.0,
#  ' Good good quality merchandise value CP': 3.3333333333333335,
#  ' Good good quality of goods shipped speed': 3.066666666666667,
#  ' Good good quality of goods shipped speed service': 3.142857142857143,
#  ' Good good quality of goods shipped speed value CP': 3.130434782608696,
#  ' Good good service delivery speed': 3.1153846153846154,
#  ' Good good shipping speed delivery speed': 3.0588235294117645,
#  ' Good good shipping speed delivery speed good value CP': 3.0,
#  ' Good packaging': 3.0,
#  ' Good product price product price good quality good products': 3.0,
#  ' Good product prices Response Quality good product good seller': 3.0,
#  ' Good product prices Response product quality is good good good seller Delivery speed': 3.0,
#  ' Good product prices good seller Delivery speed response good': 3.0,
#  ' Good product prices good seller Response': 3.04,
#  ' Good product quality': 3.6972034715525552,
#  ' Good product quality ': 4.25,
#  ' Good product quality  Excellent service by seller': 5.0,
#  ' Good product quality  Fast delivery': 4.5,
#  ' Good product quality  Fast delivery  Excellent service by seller': 4.5,
#  ' Good product quality  Good delivery speed  Good seller response': 3.0,
#  ' Good product quality  Good value for money': 4.375,
#  ' Good product quality  Good value for money  Excellent service by seller  Fast delivery': 4.5,
#  ' Good product quality  Good value for money  Fast delivery': 4.333333333333333,
#  ' Good product quality  Good value for money  Fast delivery  Excellent service by seller': 4.6,
#  ' Good product quality  Good value for money Fast delivery': 4.5,
#  ' Good product quality  The product price is good': 3.0,
#  ' Good product quality &  Good value for money': 4.5,
#  ' Good product quality & Good value for money': 4.5,
#  ' Good product quality ..': 3.0,
#  ' Good product quality Delivery time as expected': 2.5,
#  ' Good product quality Excellent service by seller': 4.411764705882353,
#  ' Good product quality Excellent service by seller Fast delivery': 5.0,
#  ' Good product quality Fast delivery': 4.378787878787879,
#  ' Good product quality Fast delivery Excellent service by seller': 4.393939393939394,
#  ' Good product quality Fast delivery Excellent service by seller Good value for money': 4.333333333333333,
#  ' Product quality is very good The service is great from the carrier.': 5.0,
#  ' Product quality is very good Very good service from the store.': 4.333333333333333,
#  ' Product quality is very good Very good service from the store. Speed \u200b\u200bof delivery is very good.': 5.0,
#  ' Product quality is very good Very good value': 4.491329479768786,
#  ' Product quality is very good Very good value Fast delivery, good.': 3.0,
#  ' Product quality is very good Very good value Product quality is very good': 4.25,
#  ' Product quality is very good Very good value Product quality is very good Speed \u200b\u200bof delivery is very good.': 4.0,
#  ' Product quality is very good Very good value Product quality is very good Speed \u200b\u200bof delivery is very good. Very good service from the store.': 5.0,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good.': 4.482352941176471,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. Speed \u200b\u200bof delivery is very good.': 4.5,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. Speed \u200b\u200bof delivery is very good. The service is great from the carrier.': 4.8,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. Speed \u200b\u200bof delivery is very good. Very good service from the store.': 5.0,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. The service is great from the carrier.': 4.333333333333333,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. The service is great from the carrier. Very good service from the store.': 4.25,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. Very good service from the store.': 4.526315789473684,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. Very good service from the store. The service is great from the carrier.': 4.516129032258065,
#  ' Product quality is very good Very good value Speed \u200b\u200bof delivery is very good. Very good service from the store. Very good service from the store.': 4.0,
#  ' Product quality is very good Very good value The service is great from the carrier.': 4.5,
#  ' Product quality is very good Very good value Very good service from the store.': 4.5,
#  ' Product quality is very good Very good value Very good service from the store. Speed \u200b\u200bof delivery is very good.': 4.5,
#  ' Product quality is very good Very good value Very good service from the store. The service is great from the carrier.': 4.0,
#  ' Product quality is very good Very good value Very good value': 5.0,
#  ' Product quality is very good Very good value Very good value Speed \u200b\u200bof delivery is very good.': 4.7272727272727275,
#  ' Product quality is very good Very good value Very good value Speed \u200b\u200bof delivery is very good. Very good service from the store. The service is great from the carrier.': 4.75,
#  ' Product quality is very poor product quality is poor': 1.0,
#  ' Product quality standards': 2.0355555555555553,
#  ' Product quality standards Product price Delivery speed good good good seller Response': 3.0,
#  ' Product quality standards better product prices': 2.5833333333333335,
#  ' Product quality standards product price good good Delivery speed': 2.6666666666666665,
#  ' Product quality standards.': 2.0180722891566263,
#  ' Product quality standards. Delivery speed is good.': 2.5,
#  ' Product quality standards. Free standard shipping.': 2.142857142857143,
#  ' Product quality standards. Free standard shipping. Standard seller response.': 2.25,
#  ' Product quality standards. Product quality standards.': 2.0,
#  ' Product quality standards. Product quality standards. The price of the standard product.': 2.0,
#  ' Product quality standards. Speed \u200b\u200bof delivery is good.': 1.5,
#  ' Product quality standards. Standard seller response.': 2.0,
#  ' Product quality standards. The price of the standard product.': 1.9736842105263157,
#  ' Product quality standards. The price of the standard product. Delivery speed is good.': 2.75,
#  ' Product quality standards. The price of the standard product. Delivery speed is good. Good seller response.': 2.6666666666666665,
#  ' Product quality standards. The price of the standard product. Delivery speed is very good.': 3.0,
#  ' Product quality standards. The price of the standard product. Free standard shipping.': 2.05,
#  ' Product quality standards. The price of the standard product. Free standard shipping. Standard seller response.': 2.0526315789473686,
#  ' Product quality standards. The price of the standard product. Standard seller response.': 2.0,
#  ' Product quality standards. The product price is good.': 3.0,
#  ' Product quality standards. The product price is good. Delivery speed is good.': 3.0,
#  ' Product quality temporary': 2.0412371134020617,
#  ' Response excellent seller excellent product quality': 4.333333333333333,
#  ' Response excellent seller excellent product quality excellent product price': 4.0,
#  ' Response excellent seller excellent product quality excellent product price is very good delivery speed': 5.0,
#  ' Response good seller good product price': 3.0,
#  ' Response good seller good product price good delivery speed is good product quality': 3.5,
#  ' Response good seller good product price product quality is good': 3.0,
#  ' Response good seller good product quality': 2.75,
#  ' Response good seller good product quality is good product price': 3.0,
#  ' Response good seller good shipping speed': 3.0,
#  ' Response is very good seller very good product price': 4.333333333333333,
#  ' Response is very good seller very good seller response speed is very good delivery very good product price Product quality is very good': 4.0,
#  ' Response product quality good good seller good product price': 3.0,
#  ' Response product quality is not good not good seller': 1.0,
#  ' Response product quality is not good not good seller Delivery speed is not good': 1.0,
#  ' Response seller unfavorable': 1.0,
#  ' Response seller unfavorable.': 1.0,
#  ' Response speed of a good delivery good seller': 3.021276595744681,
#  ' Response standard product quality good seller': 2.5,
#  ' Response standard product quality standards seller': 1.5,
#  ' Responsive seller': 2.0,
#  ' Rude seller': 1.0,
#  ' Seller not responsive': 1.0,
#  ' Service by seller is ok': 2.0,
#  ' Services provided by the nice shops. Fast delivery, good.': 3.0,
#  ' Services provided by the nice shops. Good service from the carrier.': 3.0,
#  ' Shop Shop very good service very good service': 4.0,
#  ' Shop is well worth the money very good service': 3.0,
#  ' Shop serves poor': 1.0,
#  ' Shop serves pretty good': 3.0,
#  ' Shop serves pretty good Value for Money': 3.0,
#  ' Shop serves very good': 4.430769230769231,
#  ' Shop serves very good product packaging is very beautiful and certainly': 4.0,
#  ' Shop serves very good quality excellent product': 4.5,
#  ' Shop serves very good very fast delivery time': 4.714285714285714,
#  ' Shop serves very poor': 1.0,
#  ' Shop serves very well Very worth the money': 5.0,
#  ' Shop serves very well Very worth the money very fast delivery time': 4.666666666666667,
#  ' Shop service is temporarily': 2.0,
#  ' Slow delivery time': 1.0,
#  ' Speed \u200b\u200bof delivery Poor. Poor service from the store.': 1.0,
#  ' Speed \u200b\u200bof delivery Poor. Speed \u200b\u200bof delivery Poor.': 1.0,
#  ' Speed \u200b\u200bof delivery Poor. Speed \u200b\u200bof delivery Poor. Speed \u200b\u200bof delivery Poor.': 1.0,
#  ' Speed \u200b\u200bof delivery is good': 1.1764705882352942,
#  ' Speed \u200b\u200bof delivery is good.': 1.3888888888888888,
#  ' Speed \u200b\u200bof delivery is good. The response is not good sellers.': 1.1111111111111112,
#  ' Speed \u200b\u200bof delivery is the product quality is not good either': 1.0,
#  " Speed \u200b\u200bof delivery is the seller's response is not good either": 1.0,
#  ' Speed \u200b\u200bof delivery is very good. Good value': 3.0,
#  ' Speed \u200b\u200bof delivery is very good. Product quality is very good': 4.8,
#  ' Speed \u200b\u200bof delivery is very good. Speed \u200b\u200bof delivery is very good.': 4.111111111111111,
#  ' Speed \u200b\u200bof delivery is very good. Speed \u200b\u200bof delivery is very good. Very good value': 4.6,
#  ' Speed \u200b\u200bof delivery is very good. The service is great from the carrier.': 5.0,
#  ' Speed \u200b\u200bof delivery is very good. Very good service from the store.': 4.6,
#  ' Speed \u200b\u200bof delivery is very good. Very good service from the store. The service is great from the carrier.': 3.5,
#  ' Speed \u200b\u200bof delivery is very good. Very good value': 4.476190476190476,
#  ' Speed \u200b\u200bof delivery is very good. Very good value Product quality is very good': 4.833333333333333,
#  ' Speed \u200b\u200bof delivery is very good. Very good value Very good service from the store.': 4.5,
#  ' Speed \u200b\u200bof delivery is very poor. Terrible service from the store.': 1.0,
#  ' Standard packaging': 2.0,
#  ' Standard packaging  OK quality': 2.0,
#  ' Standard product price': 2.076923076923077,
#  ' Standard product price product quality good': 3.0,
#  ' Standard product quality quality standard product standard product price': 2.0,
#  ' Standard product quality quality standard products': 2.0,
#  ' Standard product quality standard product price': 2.0352941176470587,
#  ' Standard product quality standard product price good delivery Speed': 2.6666666666666665,
#  ' Standard product quality standard product price good delivery speed is good seller Response': 3.0,
#  ' Standard product quality standard product price is very good delivery speed good seller Response': 2.5,
#  " Standard product quality standard product price is very good delivery speed is very good seller's response": 2.5,
#  ' Standard product quality standard product price less good delivery Speed \u200b\u200bResponse standard seller': 2.0,
#  ' Standard product quality standard product price seller Response standard standard delivery Speed': 2.0,
#  ' Standard product quality standard product price standard delivery Speed': 2.0357142857142856,
#  ' Standard product quality standard product price standard delivery Speed \u200b\u200bResponse Response standards seller seller standards': 2.5,
#  ...}

# %%
def remove_non_ascii(text):
    return ''.join(i for i in text if ord(i) < 128)

def process_text(text):
    text = remove_non_ascii(text)                # remove non-ascii
    text = text.lower()                          # lowercase
    text = re.sub(r'[^A-Za-z0-9 ]+', '', text)   # remove all non-alphanum chars
    text = text.strip()                          # remove trailing whitespaces
    text = re.sub(r'\s+', ' ', text)             # remove multiple whitespaces
    return text

# %%
def remove_stopwords(text, stop_words):
    return list(filter(lambda word: word not in stop_words, text))

# %%
def get_wordnet_pos(word):
    # Map POS tag to first character lemmatize() accepts
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": nltk.corpus.wordnet.ADJ,
                "N": nltk.corpus.wordnet.NOUN,
                "V": nltk.corpus.wordnet.VERB,
                "R": nltk.corpus.wordnet.ADV}

    return tag_dict.get(tag, nltk.corpus.wordnet.NOUN)

def lemmatize_tokens(tokens, lemmatizer):
    lemmatized = []
    for token in tokens:
        lemmatized.append(lemmatizer.lemmatize(token, get_wordnet_pos(token)))
    return " ".join(lemmatized)

# %%
def process_column(col):
    stop_words = set(nltk.corpus.stopwords.words("english"))
    wordnet_lemmatizer = nltk.stem.WordNetLemmatizer()

    col = col.apply(lambda x: process_text(x))
    col = col.apply(lambda x: nltk.tokenize.word_tokenize(x))
    col = col.apply(lambda x: remove_stopwords(x, stop_words))
    col = col.apply(lambda x: lemmatize_tokens(x, wordnet_lemmatizer))

    return col

if not CLEAN_PATH.exists():
    df['review'] = process_column(df['review'])
    df = df.dropna()
    df = df[df['review'].map(lambda x: len(str(x)) > 3)]
    df.to_csv(CLEAN_PATH, index = False)
    print("Output to {}".format(CLEAN_PATH))
# Out:
# Output to data/clean.csv

# %%
df.head()
# Out:
#    review_id                                             review  rating
# 0          0  ga disappointed neat product meletot hilsnyaa ...       1
# 1          1     rdtanya replace broken glass broken chargernya       1
# 2          2  nyesel bngt dsni shopping antecedent photo mes...       1
# 3          3           sent light blue suit good ga want refund       1
# 4          4  pendant come dent scratch surface coat look li...       1

# %%
df.shape
# Out:
# (146624, 3)

# %% [markdown]
# ## Preparing Data

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(df['review'])
vocab_size = len(tokenizer.word_index) + 1

print("Top 10 Words")
print(list(tokenizer.word_index.items())[:10])
print()
print("Bottom 10 Words")
print(list(tokenizer.word_index.items())[-10:])
# Out:
# Top 10 Words
# [('good', 1), ('product', 2), ('quality', 3), ('delivery', 4), ('seller', 5), ('price', 6), ('speed', 7), ('excellent', 8), ('awesome', 9), ('fast', 10)]
#
# Bottom 10 Words
# [('kemvaliannya', 66587), ('paketanmakasih', 66588), ('kaklancar', 66589), ('jualannyasemakin', 66590), ('nyaharganyas', 66591), ('dikntong', 66592), ('wid19', 66593), ('brosny', 66594), ('supercuteee', 66595), ('baguuuuuuuuuuuus', 66596)]

# %%
sequences = tokenizer.texts_to_sequences(df['review'])
max_seq_len = 0
for seq in sequences:
    if len(seq) > max_seq_len:
        max_seq_len = len(seq)

padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(sequences, maxlen = max_seq_len, padding='post')

print(max_seq_len)
print(padded_sequences.shape)
# Out:
# 174
# (146624, 174)

# %%
df['zero_idx_rating'] = df['rating'] - 1
one_hot_ratings = tf.keras.utils.to_categorical(df['zero_idx_rating'], num_classes = 5)
one_hot_ratings.shape
# Out:
# (146624, 5)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences,
    one_hot_ratings,
    test_size = 0.2,
    random_state = SEED
)
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (117299, 174) (29325, 174)
# (117299, 5) (29325, 5)

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) \
                        .cache() \
                        .shuffle(BATCH_SIZE * 40, seed = SEED) \
                        .repeat() \
                        .batch(BATCH_SIZE) \
                        .prefetch(tf.data.experimental.AUTOTUNE)

# %%
validation_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)) \
                        .batch(BATCH_SIZE) \
                        .prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Training Model

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Embedding(vocab_size, EMBEDDING_DIMS, input_length = max_seq_len))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(EMBEDDING_DIMS)))
model.add(tf.keras.layers.Dense(EMBEDDING_DIMS, activation = 'relu'))
model.add(tf.keras.layers.Dense(5, activation='softmax'))

model.compile(
    optimizer = tf.keras.optimizers.Adam(),
    loss = tf.keras.losses.CategoricalCrossentropy(),
    metrics = ["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 174, 300)          19979100
# _________________________________________________________________
# bidirectional (Bidirectional (None, 600)               1442400
# _________________________________________________________________
# dense (Dense)                (None, 300)               180300
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 1505
# =================================================================
# Total params: 21,603,305
# Trainable params: 1,624,205
# Non-trainable params: 19,979,100
# _________________________________________________________________

# %%
history = model.fit(
    train_ds,
    epochs = 50,
    steps_per_epoch = len(X_train) // BATCH_SIZE,
    validation_data = validation_ds,
    validation_steps = len(X_test) // BATCH_SIZE,
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            patience = 3,
            restore_best_weights = True,
            verbose = 1,
            monitor = "val_accuracy",
            mode = "max"
        ),
        tf.keras.callbacks.CSVLogger(str(log_path), append = True),
        tf.keras.callbacks.ModelCheckpoint(
            str(checkpoint_path),
            monitor = "val_accuracy",
            mode = "max",
            save_best_only = True
        )
    ]
)
# Out:
# Epoch 1/10
# 1832/1832 [==============================] - 262s 143ms/step - loss: 1.1665 - accuracy: 0.4414 - val_loss: 1.1225 - val_accuracy: 0.4609
# Epoch 2/10
#   29/1832 [..............................] - ETA: 3:47 - loss: 1.1267 - accuracy: 0.4467
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-74d7d35e9028> in <module>()
#      18             monitor = "val_accuracy",
#      19             mode = "max",
# ---> 20             save_best_only = True
#      21         )
#      22     ]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
acc = history.history["accuracy"]
loss = history.history["loss"]
validation_acc = history.history["val_accuracy"]
validation_loss = history.history["val_loss"]

epochs_range = range(len(history.history["accuracy"]))

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label = "Training Accuracy")
plt.plot(epochs_range, validation_acc, label = "Validation Accuracy")
plt.legend(loc = "lower right")
plt.title("Training and Validation Accuracy")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label = "Training Loss")
plt.plot(epochs_range, validation_loss, label = "Validation Loss")
plt.legend(loc = "lower right")
plt.title("Training and Validation Loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-007459ff489a> in <module>()
# ----> 1 acc = history.history["accuracy"]
#       2 loss = history.history["loss"]
#       3 validation_acc = history.history["val_accuracy"]
#       4 validation_loss = history.history["val_loss"]
#       5
#
# NameError: name 'history' is not defined

# %%
test_df = pd.read_csv(TEST_PATH)
test_df['review'] = process_column(test_df['review'])
test_df.head()
# Out:
#    review_id                                             review
# 0          1  great danger cool motif cantik2 jg model deliv...
# 1          2                            one shade dont fit well
# 2          3                                        comfortable
# 3          4  fast delivery product expiry dec 2022 product ...
# 4          5  sooooo cute like play glitter well browsing ph...

# %%
test_sequences = tokenizer.texts_to_sequences(test_df['review'])
test_padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen = max_seq_len, padding='post')
test_padded_sequences
# Out:
# array([[  77,  916,  123, ...,    0,    0,    0],
#        [  50, 1566,  549, ...,    0,    0,    0],
#        [ 201,    0,    0, ...,    0,    0,    0],
#        ...,
#        [   2,    3,    8, ...,    0,    0,    0],
#        [ 596,   29,   20, ...,    0,    0,    0],
#        [ 862,   13,  972, ...,    0,    0,    0]], dtype=int32)

# %%
predicted_ratings = model.predict(test_padded_sequences)
predicted_ratings_cat = np.argmax(predicted_ratings, axis = 1) + 1
predicted_ratings_cat
# Out:
# array([3, 3, 4, ..., 4, 4, 4])

# %%
output_df = test_df.copy()
output_df['rating'] = predicted_ratings_cat
output_df.head()
# Out:
#    review_id                                             review  rating
# 0          1  great danger cool motif cantik2 jg model deliv...       3
# 1          2                            one shade dont fit well       3
# 2          3                                        comfortable       4
# 3          4  fast delivery product expiry dec 2022 product ...       4
# 4          5  sooooo cute like play glitter well browsing ph...       4

# %%
output_df = output_df.drop('review', axis = 1)
output_df.to_csv("./data/predictions.csv", index = False)
